# %% [markdown]
# #### Importing relevant libraries

# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# #### Reading our dataset!

# %%
df = pd.read_csv(r'F:\Machine Learning - All Materials and Courses\Udemy\Python for Data Science and Machine Learning Bootcamp\Programs\NN and Deep Learning\TF - Classification\cancer_classification.csv')

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  radius error  texture error  perimeter error  \
# ...

# %% [markdown]
# #### Splitting the data into training and testing subsets

# %%
X = df.drop('benign_0__mal_1', axis=1).values
y = df['benign_0__mal_1'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=101)

# %% [markdown]
# #### Scaling the predictors

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard

# %% [markdown]
# Initializing early-stopping

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

# %%
pwd
# Out:
# 'f:\\Machine Learning - All Materials and Courses\\Udemy\\Python for Data Science and Machine Learning Bootcamp\\Programs\\NN and Deep Learning\\Tensorboard'

# %%
from datetime import datetime

# %%
datetime.now().strftime("%Y-%m-%d--%H%M")
# Out:
# '2024-06-22--0000'

# %%
log_directory = 'logs\\fit'
timestamp = datetime.now().strftime("%Y-%m-%d--%H%M")
log_directory = log_directory + "\\" + timestamp

board = TensorBoard(log_dir=log_directory, histogram_freq=1,
                    write_graph=True,
                    write_images=True,
                    update_freq='epoch',
                    profile_batch=2,
                    embeddings_freq=1)

# %% [markdown]
# #### Building the model

# %%
model = Sequential()

# input layer
model.add(Dense(units=30, activation='relu'))
model.add(Dropout(0.5))

# hidden layer
model.add(Dense(units=15, activation='relu'))
model.add(Dropout(0.5))

# output layer
model.add(Dense(units=1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam')

# %% [markdown]
# Training our model!

# %%
model.fit(x=X_train, y=y_train, epochs=600, validation_data=(X_test, y_test),
          verbose=1, callbacks=[early_stop, board])
# Out:
# Epoch 1/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.6858 - val_loss: 0.6713
# Epoch 2/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6735 - val_loss: 0.6562
# Epoch 3/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6677 - val_loss: 0.6423
# Epoch 4/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.6529 - val_loss: 0.6301
# Epoch 5/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.6366 - val_loss: 0.6126
# Epoch 6/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6425 - val_loss: 0.5952
# Epoch 7/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.6168 - val_loss: 0.5776
# Epoch 8/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6091 - val_loss: 0.5555
# Epoch 9/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5944 - val_loss: 0.5327
# Epoch 10/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5653 - val_loss: 0.5064
# Epoch 11/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5358 - val_loss: 0.4786
# ...

# %% [markdown]
# #### Running Tensorboard!

# %%
print(log_directory)
# Out:
# logs\fit\2024-06-22--0003

# %%
pwd
# Out:
# 'f:\\Machine Learning - All Materials and Courses\\Udemy\\Python for Data Science and Machine Learning Bootcamp\\Programs\\NN and Deep Learning\\Tensorboard'
